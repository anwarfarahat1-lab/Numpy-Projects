# %% [markdown]
# # **NumPy Retail Analyze**

# %%
# Libarry
import numpy as np

# %%
# total_units_sold
product_names = np.array(['Laptop', 'Phone', 'Headphones','Charger','Camera'
                          , 'Tablet' , 'Monitor','keyboard','Speaker','Mouse'])
total_units_sold = np.array([1324, 1355, 1240, 1183,1268 , 1222 ,1150 , 1136 , 1347 , 1244])
# ======================================================================
# ======================================================================
# total_profit_per_product
total_profit_per_product = np.array([182267.86 , 113836.12 , 139709.45 , 28075.13 , 78298.16
                                     ,132765.7 , 170159.46 , 135034.99 , 204909.12 , 175222.69])
# ======================================================================
# ======================================================================
# Weekly Revenue
weekly_revenue = np.array([374195 , 399162 , 296756, 316470 , 332787 ,285128 ,301523
                           ,308877 , 361441 , 306197 , 401453 , 323387])
# ======================================================================
# ======================================================================
# weekly_profit_growth_rate
weekly_profit_growth_rate = np.array([ -1.71 , -19.14 ,  7.26,   1.84 ,-18.65,  10.82,  -5.16 , 24.91, -21.71,  44.79 ,
                                      -24.24])
# ======================================================================
# ======================================================================
# Avreage Weekly Profit
average_weekly_profit = 113356.56
low_stock_products = []
# ======================================================================
# ======================================================================
# Summary Report
num_products = len(product_names)
avreage_units_sold = total_units_sold.mean()
avereage_profit_margin_precent = 35.49
most_sold_idx = np.argmax(total_units_sold)
most_profitable_idx = np.argmax(total_profit_per_product)

# %%
# ======================================================================
# Show The Output
print('='*50 , "NumPy Retail Analyze" , '='*50)
print("Total Units Sold per Product:")
print(total_units_sold.tolist())
print()
print()
# ======================================================================
print("Total Profit per Product:")
print(np.round(total_profit_per_product, 2).tolist())
print()
print()
# ======================================================================
print("Most Sold Product:", product_names[most_sold_idx])
print("Most Profitable Product:", product_names[most_profitable_idx])
print()
print()
# ======================================================================
print("Average Weekly Profit:", f"{average_weekly_profit:.2f}")
print()
print()
# ======================================================================
print("Weekly Profit Growth Rate (%):")
print(weekly_profit_growth_rate.tolist())
print()
print()
# ======================================================================
print("Products with Low Remaining Stock:")
print("None" if len(low_stock_products) == 0 else ", ".join(low_stock_products))
print()
print()
# ======================================================================
print("Summary Report:")
print(f"- Number of Products: {num_products}")
print(f"- Average Units Sold per Product: {average_units_sold:.1f}")
print(f"- Average Profit Margin: {average_profit_margin_percent:.2f} %")
print()
print()
# Out:
# ================================================== NumPy Retail Analyze ==================================================
# Total Units Sold per Product:
# [1324, 1355, 1240, 1183, 1268, 1222, 1150, 1136, 1347, 1244]
#
#
# Total Profit per Product:
# [182267.86, 113836.12, 139709.45, 28075.13, 78298.16, 132765.7, 170159.46, 135034.99, 204909.12, 175222.69]
#
#
# Most Sold Product: Phone
# Most Profitable Product: Speaker
#
#
# Average Weekly Profit: 113356.56
#
#
# Weekly Profit Growth Rate (%):
# [-1.71, -19.14, 7.26, 1.84, -18.65, 10.82, -5.16, 24.91, -21.71, 44.79, -24.24]
#
#
# Products with Low Remaining Stock:
# None
#
#
# Summary Report:
# - Number of Products: 10
# - Average Units Sold per Product: 1246.9
# - Average Profit Margin: 35.49 %
